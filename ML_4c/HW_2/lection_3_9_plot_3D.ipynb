# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('ph-data.csv')
labels = df['label']
labels.loc[labels < 6] = -1
labels.loc[labels > 9] = 1
labels.loc[labels > 5] = 0

# %%
df.head(7)
# Out:
#    blue  green  red  label
# 0    36     27  231     -1
# 1    36     84  250     -1
# 2    37    164  255     -1
# 3    22    205  255     -1
# 4    38    223  221     -1
# 5    29    214  148     -1
# 6     0    181   76      0

# %%
fig=plt.figure()
threedee = fig.add_subplot(projection='3d')
threedee.scatter(df['red'], df['green'], df['blue'])
threedee.set_xlabel('Blue')
threedee.set_ylabel('Green')
threedee.set_zlabel('Red')
plt.show()

# %% [markdown]
# ## Добавим цветовую раскраску и возможность вращения построенного графика

# %%
import numpy as np
colormap = np.array(['r', 'g', 'b'])
res = colormap[df['label']+1]

# %%
print(res[:15])
# Out:
# ['r' 'r' 'r' 'r' 'r' 'r' 'g' 'g' 'g' 'g' 'b' 'b' 'b' 'b' 'b']

# %%
# %matplotlib notebook
threedee = plt.figure().gca(projection='3d')
threedee.scatter(df['blue'], df['green'], df['red'], c=colormap[df['label']+1])
threedee.set_xlabel('Blue')
threedee.set_ylabel('Green')
threedee.set_zlabel('Red')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ![3d_rgb.png](attachment:3d_rgb.png)
