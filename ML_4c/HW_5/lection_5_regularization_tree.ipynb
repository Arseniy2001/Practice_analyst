# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_moons
from plot_region import *

# %%
X,y = make_moons(n_samples=2000, noise=0.5, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
clfr = DecisionTreeClassifier()
clfr.fit(X_train, y_train) 
PlotResultRegion(clfr, X, y, h = 0.02)

# %%
type(X_train)
idxs = np.random.permutation(X_train.shape[0])[:-50]
X_train2 = X_train[idxs]
y_train2 = y_train[idxs]

# %%
clfr2 = DecisionTreeClassifier()
clfr2.fit(X_train2, y_train2) 
PlotResultRegion(clfr2, X, y, h = 0.02)
