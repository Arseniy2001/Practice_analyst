# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
housing = datasets.load_boston()

# %%
df = pd.DataFrame(housing.data, columns = housing.feature_names)
df.head()
y = housing.target
df2 = df.copy()
df2['y'] = y

# %%
scatter = pd.plotting.scatter_matrix(df2, alpha=0.5, figsize = (15,15))

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.3, random_state=1)

# %%
model0 = LinearRegression();

# %%
model0.fit(X_train, y_train);

# %%
y_pred0 = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred0)
# Out:
# 17.92941475850609

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.pipeline import Pipeline
model = Pipeline([("scalar", PolynomialFeatures(2)),
                 ("estimator", LinearRegression())])

# %%
model.fit(X_train, y_train);

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 17.92941475850609

# %%
from sklearn.linear_model import Lasso

# %%
modelL1 = Lasso(alpha=0.01)
modelL1 = Pipeline([("scalar", PolynomialFeatures(2)),
                 ("estimator", Lasso(alpha=0.1,max_iter=10000, tol=1e-1))])

# %%
modelL1.fit(X_train, y_train);

# %%
y_predL1 = modelL1.predict(X_test)

# %%
mean_squared_error(y_test, y_predL1)
# Out:
# 11.14061314372606

# %%
from sklearn.linear_model import Ridge

# %%
modelL2 = Ridge(alpha=1)
modelL2 = Pipeline([("scalar", PolynomialFeatures(2)),
                 ("estimator", Ridge(alpha=100000))])

# %%
modelL2.fit(X_train, y_train);

# %%
y_predL2 = modelL2.predict(X_test)

# %%
mean_squared_error(y_test, y_predL2)
# Out:
# 11.84070347076446
